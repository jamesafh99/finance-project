# %% [markdown]
# # **0. Data download**
#
# **OVERVIEW**
# - This notebook acquires and stores raw daily data for a USD-based, long-only and unlevered strategic multi-asset portfolio.
# - Daily OHLCV data for all investable instruments are downloaded from **Yahoo Finance (`yfinance`)**.
# - The **DGS3MO** 3-Month Treasury Constant Maturity Rate is downloaded from **FRED** as a non-investable USD risk-free proxy for later excess-return and Sharpe-ratio calculations.
# - The analysis uses ten full calendar years: **2016-01-01** (inclusive) to **2026-01-01** (exclusive).
# - **`auto_adjust=True`** is used in **`yfinance`**, so OHLC prices are adjusted for corporate actions while retaining standard column names such as **`Close`**.
# - Downloaded source data are stored as CSV files under **`data/raw/`** without additional cleaning or analytical transformations.
# - These raw files are the inputs for subsequent data cleaning, portfolio construction, risk analysis and optimization.

# %% [markdown]
# ## **0.1 Imports**

# %%
from src.helpers_io import raw_path
from src.data_downloader import download_assets, download_risk_free, save_raw_data

# %% [markdown]
# ## **0.2 Asset universe**
#
# **PORTFOLIO MANDATE**
#
# - Strategic multi-asset portfolio denominated in USD, designed for long-term capital growth while limiting severe losses and maintaining reasonable drawdowns.
# - Long-only, unlevered and restricted to liquid, simple and investable instruments.
#
# **SELECTION PROCESS**
#
# - The universe was defined before optimization or performance analysis to avoid selecting assets based on historical results.
# - The portfolio mandate was translated into five distinct economic functions across major macroeconomic regimes and financial-stress scenarios.
# - One instrument was selected for each function based on economic exposure, diversification value, liquidity, simplicity and sufficient strategy history.
# - Corporate credit and REITs were excluded because their main risk drivers overlap substantially with equities and interest rates already represented in the portfolio.
#
# | Regime / need | Portfolio function | Asset class | Selected exposure | Instrument | Selection rationale |
# |---|---|---|---|---|---|
# | Expansion / growth | Growth engine | Equities | Global developed + emerging, all-cap | **`VT`** | Broad global equity exposure without concentrating growth risk in one country or market-cap segment |
# | Recession / disinflation | Defensive duration | Government bonds | US Treasuries 7–10Y | **`IEF`** | Meaningful Treasury duration for recession protection without the extreme rate sensitivity of long-term bonds |
# | Inflation | Inflation protection | TIPS | US TIPS 0–5Y | **`STIP`** | Direct inflation-linked exposure with limited real-rate duration, complementing rather than duplicating IEF |
# | Stagflation / supply shocks | Real-asset diversification | Commodities | Broad, production-weighted commodity futures | **`GSG`** | Broad commodity exposure with long strategy history and strong sensitivity to real supply shocks |
# | Financial stress / crisis | Crisis diversification | Gold | Physically backed gold | **`SGOL`** | Direct physical-gold exposure without mining-equity or futures-roll exposure |
#
# **RISK-FREE PROXY**
#
# - **`DGS3MO`** — 3-Month Treasury Constant Maturity Rate from FRED. It is not part of the investable universe and is used later as the USD risk-free proxy for excess-return and Sharpe-ratio calculations.

# %%
asset_universe = ["VT", "IEF", "STIP", "GSG", "SGOL"]

rf_rate_url = "https://fred.stlouisfed.org/graph/fredgraph.csv?id=DGS3MO"

start_date = "2016-01-01"
end_date = "2026-01-01"  # Exclusive

# %% [markdown]
# ## **0.3 Download data from Yahoo Finance and FRED**

# %%
raw_dir = raw_path("")
raw_dir.mkdir(parents=True, exist_ok=True)   # Ensures 'raw' folder exists

downloaded_data = download_assets(asset_universe, start_date, end_date)
risk_free = download_risk_free(rf_rate_url, start_date, end_date, date_col_name="observation_date", rf_col_name="DGS3MO")
save_raw_data(downloaded_data, risk_free, raw_dir, rf_name="DGS3MO")
